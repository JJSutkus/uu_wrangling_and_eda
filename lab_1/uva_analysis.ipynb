# %% [markdown]
# # UVA Analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('ForeignGifts_edu.csv',low_memory=False)
df.head()
# Out:
#    ID   OPEID               Institution Name          City State  \
# 0   1  102000  Jacksonville State University  Jacksonville    AL
# 1   2  104700                Troy University          Troy    AL
# 2   3  105100          University of Alabama    Tuscaloosa    AL
# 3   4  105100          University of Alabama    Tuscaloosa    AL
# 4   5  105100          University of Alabama    Tuscaloosa    AL
#
#    Foreign Gift Received Date  Foreign Gift Amount      Gift Type  \
# 0                       43738               250000  Monetary Gift
# 1                       43592               463657       Contract
# 2                       43466              3649107       Contract
# 3                       43472                 1000       Contract
# 4                       43479                49476       Contract
#
#   Country of Giftor                          Giftor Name
# 0             CHINA                                  NaN
# 1             CHINA     Confucius Institute Headquarters
# ...

# %%
#Look at other high tier public instituitons
public = df[df["Institution Name"].isin(["University of Virginia", "University of California, Los Angeles", "University of Michigan - Ann Arbor", "University of Southern California", "University of North Carolina - Chapel Hill", "University of Texas at Austin", "University of Wisconsin - Madison", "University of Illinois at Urbana-Champaign", "University of Florida"])]
public["Institution Name"].unique()
# Out:
# <StringArray>
# [     'University of California, Los Angeles',
#           'University of Southern California',
#                       'University of Florida',
#  'University of Illinois at Urbana-Champaign',
#          'University of Michigan - Ann Arbor',
#  'University of North Carolina - Chapel Hill',
#               'University of Texas at Austin',
#                      'University of Virginia',
#           'University of Wisconsin - Madison']
# Length: 9, dtype: str

# %%
#Indentify what countries and giftors contribute the most to these institutions
public.groupby(["Country of Giftor", "Giftor Name"])["Foreign Gift Amount"].sum().sort_values(ascending=False).head(10)
# Out:
# Country of Giftor  Giftor Name
# CHINA              Zhejiang University                    28540419
# JAPAN              THE JAPAN FOUNDATION TADASHI YANAI     25000000
# SWITZERLAND        Novartis                               12503307
# SAUDI ARABIA       KING ABDULAZIZ CITY FOR SCIENCE AND    11071016
# JAPAN              Kyushu University                      10735776
# SINGAPORE          Illinois at Singapore Pte Ltd          10414679
#                    Jiong Wu                               10000000
# DENMARK            Novo Nordisk A/S                        9942329
# FRANCE             Airbus S.A.S.                           9000001
# JAPAN              EISAI AMERICA, INC.                     8872734
# Name: Foreign Gift Amount, dtype: int64

# %%
public[public["Institution Name"] == "University of Virginia"].groupby(["Country of Giftor", "Giftor Name"])["Foreign Gift Amount"].sum().sort_values(ascending=False).head(10)
# Out:
# Country of Giftor  Giftor Name
# SWEDEN             AstraZeneca                            3208048
# BANGLADESH         Intrnl Centre Diarrheal Disease        1382896
# TANZANIA           Haydom Lutheran Hospital d/b/a Hayd    1100553
#                    Haydom Luther Hospital                 1035339
# GUERNSEY           Harvest Group Holding                  1000000
# SWITZERLAND        Lawrence D/ Karin S Howell             1000000
#                    Lawrence D & Karin S Howell            1000000
# FINLAND            Danisco Sweeteners Oy                   990331
# BANGLADESH         Intnl Centre for Diarrhoeal Disease     919857
#                    International Centre for Diarrhoeal     919518
# Name: Foreign Gift Amount, dtype: int64

# %% [markdown]
# **Strategy:** Similar high-tier public insitiuitons receive a lot of money from asian countries such as China, Japan, Saudi Arabia, Singapore, and others. However, UVA does not appear to receive much from these countries, so creating a relationship with giftors in these countries could offer a new source of foreign money for the institution. Additionally, Qatar and England are two major contributors to the market as a whole being the first and second highest giftors. UVA does not appear to receive much from these nations opening another potential avenue to draw foreign money from.
